# %%
import pickle
import matplotlib.pyplot as plt

# %%
model = pickle.load(open('modeldump.pkl', 'rb'))

# %%
for x in model.keys():
    print(x)
# Out:
# sat_infer/lits1:0
# sat_infer/lits2:0
# sat_infer/clauses:0
# sat_infer/layer_0/lits_msg_1/weight:0
# sat_infer/layer_0/lits_msg_1/bias:0
# sat_infer/layer_0/lits_msg_3/weight:0
# sat_infer/layer_0/lits_msg_3/bias:0
# sat_infer/layer_0/clauses_layer/kernel:0
# sat_infer/layer_0/clauses_layer/input/gamma:0
# sat_infer/layer_0/clauses_layer/input/beta:0
# sat_infer/layer_0/clauses_layer/transform/gamma:0
# sat_infer/layer_0/clauses_layer/transform/beta:0
# sat_infer/layer_0/clauses_layer/forget/gamma:0
# sat_infer/layer_0/clauses_layer/forget/beta:0
# sat_infer/layer_0/clauses_layer/output/gamma:0
# sat_infer/layer_0/clauses_layer/output/beta:0
# sat_infer/layer_0/clauses_layer/state/gamma:0
# sat_infer/layer_0/clauses_layer/state/beta:0
# sat_infer/layer_0/clauses_msg_1/weight:0
# sat_infer/layer_0/clauses_msg_1/bias:0
# sat_infer/layer_0/clauses_msg_3/weight:0
# sat_infer/layer_0/clauses_msg_3/bias:0
# sat_infer/layer_0/lits_layer/kernel:0
# ...

# %%
axises = [4,3]
plt.plot(*zip(*model['sat_infer/lits1:0'][:,axises]), '.')
